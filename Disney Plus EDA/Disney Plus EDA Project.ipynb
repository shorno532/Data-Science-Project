# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("disney_plus_titles.csv")

# %%
df
# Out:
#      show_id     type                           title  \
# 0         s1    Movie                   A Spark Story
# 1         s2    Movie                  Spooky Buddies
# 2         s3    Movie          The Fault in Our Stars
# 3         s4  TV Show                 Dog: Impossible
# 4         s5  TV Show  Spidey And His Amazing Friends
# ...      ...      ...                             ...
# 1363   s1364    Movie          The Sword in the Stone
# 1364   s1365    Movie                 Those Calloways
# 1365   s1366  TV Show            Disney Kirby Buckets
# 1366   s1367  TV Show                  Disney Mech-X4
# 1367   s1368  TV Show              Imagination Movers
#
#                         director  \
# 0     Jason Sterman, Leanne Dare
# 1                   Robert Vince
# 2                     Josh Boone
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1363         Wolfgang Reitherman
# 1364                Norman Tokar
# ...

# %%
df.shape
# Out:
# (1368, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1368 non-null   object
#  1   type          1368 non-null   object
#  2   title         1368 non-null   object
#  3   director      928 non-null    object
#  4   cast          1194 non-null   object
#  5   country       1193 non-null   object
#  6   date_added    1365 non-null   object
#  7   release_year  1368 non-null   int64
#  8   rating        1366 non-null   object
#  9   duration      1368 non-null   object
#  10  listed_in     1368 non-null   object
#  11  description   1368 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 128.4+ KB

# %%
# missing value
df.isna().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        440
# cast            174
# country         175
# date_added        3
# release_year      0
# rating            2
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
df.type
# Out:
# 0         Movie
# 1         Movie
# 2         Movie
# 3       TV Show
# 4       TV Show
#          ...
# 1363      Movie
# 1364      Movie
# 1365    TV Show
# 1366    TV Show
# 1367    TV Show
# Name: type, Length: 1368, dtype: object

# %%
df.type.value_counts()
# Out:
# Movie      991
# TV Show    377
# Name: type, dtype: int64

# %%
df.country
# Out:
# 0                         NaN
# 1       United States, Canada
# 2               United States
# 3               United States
# 4               United States
#                 ...
# 1363            United States
# 1364            United States
# 1365            United States
# 1366                   Canada
# 1367            United States
# Name: country, Length: 1368, dtype: object

# %%
df.country.value_counts()
# Out:
# United States                                      976
# United States, Canada                               28
# United Kingdom                                      23
# United States, United Kingdom                       19
# Canada, United States                               17
#                                                   ...
# United Kingdom, United States, Canada                1
# United States, Germany, Ireland, United Kingdom      1
# United States, United Kingdom, South Africa          1
# United Kingdom, United States, Ireland               1
# New Zealand, United States                           1
# Name: country, Length: 87, dtype: int64

# %%
df.type.value_counts().plot(kind ="pie",explode=[0,0.05],autopct ='%1.2f%%'); #movie & tv show kotho percentage ase seta dekhanor jnono [autopct ='%1.1f%%]

# %%
df.type.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
#matplotlib er deffult value
inline_rc = dict(mpl.rcParams)

# %%
sns.set_theme(style='whitegrid',palette='Set2')
sns.countplot(x ='type',data=df);

# %%
#remove warnings
import warnings
warnings.filterwarnings('ignore')

# %%
mpl.rc_file_defaults()
mpl.rcParams.update(inline_rc)

# %%
sns.set_theme(style='whitegrid',palette='rocket_r');
#ratting
sns.countplot(x ='rating',data=df);

# %%
#release_year
df.release_year
# Out:
# 0       2021
# 1       2011
# 2       2014
# 3       2019
# 4       2021
#         ...
# 1363    1963
# 1364    1965
# 1365    2014
# 1366    2016
# 1367    2008
# Name: release_year, Length: 1368, dtype: int64

# %%
df.release_year.value_counts()
# Out:
# 2020    109
# 2019     97
# 2021     82
# 2017     67
# 2018     65
#        ...
# 1928      1
# 1970      1
# 1944      1
# 1945      1
# 1968      1
# Name: release_year, Length: 90, dtype: int64

# %%
#distribution plot
sns.displot(x = 'release_year',data = df,kde = True);

# %%
#TV SERIES RATING,MOVIE RATING CHECK ,kon type r ratting kamon 
sns.countplot(x ='rating',data = df, hue ='type');

# %%
#tv series duration
sns.countplot(x ='duration',data = df,hue ='type')
# Out:
# <AxesSubplot:xlabel='duration', ylabel='count'>

# %%
df[df['type']=='TV Show'] #type -->er moddhe jegula tv show  ei column gula
# Out:
#      show_id     type                                    title director  \
# 3         s4  TV Show                          Dog: Impossible      NaN
# 4         s5  TV Show           Spidey And His Amazing Friends      NaN
# 5         s6  TV Show                       Star Wars: Visions      NaN
# 13       s14  TV Show                          Life Below Zero      NaN
# 14       s15  TV Show  Miraculous: Tales Of Ladybug & Cat Noir      NaN
# ...      ...      ...                                      ...      ...
# 1344   s1345  TV Show                         X-Men: Evolution      NaN
# 1360   s1361  TV Show                                Smart Guy      NaN
# 1365   s1366  TV Show                     Disney Kirby Buckets      NaN
# 1366   s1367  TV Show                           Disney Mech-X4      NaN
# 1367   s1368  TV Show                       Imagination Movers      NaN
#
#                                                    cast  \
# ...

# %%
df[df['type']== 'Movie']#fillter out korlam
# Out:
#      show_id   type                                     title  \
# 0         s1  Movie                             A Spark Story
# 1         s2  Movie                            Spooky Buddies
# 2         s3  Movie                    The Fault in Our Stars
# 6         s7  Movie               Confessions of a Shopaholic
# 7         s8  Movie                Descendants: Royal Wedding
# ...      ...    ...                                       ...
# 1359   s1360  Movie  Lady and the Tramp II: Scamp's Adventure
# 1361   s1362  Movie                  The Cat from Outer Space
# 1362   s1363  Movie                 The Great Mouse Detective
# 1363   s1364  Movie                    The Sword in the Stone
# 1364   s1365  Movie                           Those Calloways
#
#                                       director  \
# 0                   Jason Sterman, Leanne Dare
# 1                                 Robert Vince
# 2                                   Josh Boone
# ...

# %%
#tv serial duration
sns.countplot(y ='duration',data=df[df['type']=='TV Show'],palette='bright');

# %%
#movie jono duration
sns.countplot(y ='duration',data= df[df['type']== 'Movie'],palette='bright');

# %%
#rating for movie
sns.countplot(x ='rating',data = df[df['type']=='Movie'],palette='bright');

# %%
 df[df['type']=='Movie'].director.value_counts()[:10].plot(kind ='bar',color='brown')
# Out:
# <AxesSubplot:>

# %%
#oldest movie # then sort korte hbe
old=df[df['type']=='Movie'].sort_values('release_year')

# %%
old
# Out:
#      show_id   type                                              title  \
# 1146   s1147  Movie                                   Steamboat Willie
# 1104   s1105  Movie                                   Santa's Workshop
# 819     s820  Movie                                  Flowers and Trees
# 662     s663  Movie                                 Babes in the Woods
# 1345   s1346  Movie                                      Ye Olden Days
# ...      ...    ...                                                ...
# 86       s87  Movie                               Orca vs. Great White
# 85       s86  Movie  Miraculous World: Shanghai, The Legend of Lady...
# 82       s83  Movie                      World's Most Dangerous Shark?
# 78       s79  Movie  Shark Attack Investigation: The Paige Winter S...
# 0         s1  Movie                                      A Spark Story
#
#                         director  \
# 1146      Walt Disney, Ub Iwerks
# 1104             Wilfred Jackson
# ...

# %%
old[['title','release_year']][:10]
# Out:
#                          title  release_year
# 1146          Steamboat Willie          1928
# 1104          Santa's Workshop          1932
# 819          Flowers and Trees          1932
# 662         Babes in the Woods          1932
# 1345             Ye Olden Days          1933
# 1288         Three Little Pigs          1933
# 1243            The Pied Piper          1933
# 848   Grasshopper and the Ants          1934
# 1282       The Wise Little Hen          1934
# 1180          The Big Bad Wolf          1934
